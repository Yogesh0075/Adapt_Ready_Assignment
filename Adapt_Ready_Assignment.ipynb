# %% [markdown]
# <b><h2><center>ADAPT READY ASSIGNMENT.</center>

# %% [markdown]
# <b>Question : 1

# %% [markdown]
# <b>1. Data set reference link: https://www.consumerfinance.gov/data-research/consumer-complaints/#download-the-data <br>
# File data source: https://files.consumerfinance.gov/ccdb/complaints.csv.zip <br>
# Problem statement: <br>
# Download the data from the file data source and provide possible data insights.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
sns.set(style='darkgrid')
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r'C:\My Documents\Adapt Ready Assignment Excelr\complaints.csv')

# %%
data.head()
# Out:
#   Date received                                            Product  \
# 0    2024-01-24  Credit reporting or other personal consumer re...
# 1    2024-02-26  Credit reporting or other personal consumer re...
# 2    2024-01-26  Credit reporting or other personal consumer re...
# 3    2024-01-26  Credit reporting or other personal consumer re...
# 4    2024-01-18  Credit reporting or other personal consumer re...
#
#         Sub-product                                 Issue  \
# 0  Credit reporting  Incorrect information on your report
# 1  Credit reporting  Incorrect information on your report
# 2  Credit reporting  Incorrect information on your report
# 3  Credit reporting           Improper use of your report
# 4  Credit reporting  Incorrect information on your report
#
#                                        Sub-issue  \
# 0                  Account information incorrect
# 1            Information belongs to someone else
# 2            Information belongs to someone else
# ...

# %%
data.tail()
# Out:
#         Date received                                            Product  \
# 5157096    2023-08-02  Credit reporting, credit repair services, or o...
# 5157097    2023-08-02          Payday loan, title loan, or personal loan
# 5157098    2023-08-02                                           Mortgage
# 5157099    2023-08-02  Credit reporting, credit repair services, or o...
# 5157100    2023-08-04          Payday loan, title loan, or personal loan
#
#               Sub-product                                              Issue  \
# 5157096  Credit reporting               Incorrect information on your report
# 5157097  Installment loan  Problem with additional add-on products or ser...
# 5157098      FHA mortgage                         Struggling to pay mortgage
# 5157099  Credit reporting                        Improper use of your report
# 5157100       Payday loan         Charged fees or interest you didn't expect
#
#                                              Sub-issue  \
# ...

# %% [markdown]
# <b>Understanding the Dataset:<br>
#
# 1.Date received - The date CFPB received the complaint. For example, “05/25/2013.”<br>
#
# 2.Product	- The type of product the consumer identified in the complaint. For example, “Checking or savings account” or “Student loan.”
#
# 3.Sub-product - The type of sub-product the consumer identified in the complaint. For example, “Checking account” or “Private student loan.”
#
# 4.Issue - The issue the consumer identified in the complaint. For example, “Managing an account” or “Struggling to repay your loan.”
#
# 5.Sub-issue - The sub-issue the consumer identified in the complaint. For example, “Deposits and withdrawals” or “Problem lowering your monthly payments.”
#
# 6.Consumer complaint narrative - Consumer complaint narrative is the consumer-submitted description of “what happened” from the complaint. Consumers must opt-in to share their narrative. It will not be published,unless the consumer consents, and consumers can opt-out at any time. The CFPB takes reasonable steps to scrub personal information from each complaint that could be used to identify the consumer.
#
# 7.Company public response - The company’s optional, public-facing response to a consumer’s complaint. Companies can choose to select a response from a pre-set list of options that will be posted on the public database. For example, “Company believes complaint is the result of an isolated error.”
#
# 8.Company - The complaint is about this company. For example, “ABC Bank.”
#
# 9.State - The state of the mailing address provided by the consumer.
#
# 10.ZIP code - The mailing ZIP code provided by the consumer. This field may: i) include the first five digits of a ZIP code; ii) include the first three digits of a ZIP code (if the consumer consented to publication of their complaint narrative); or iii) be blank (if ZIP codes have been submitted with non-numeric values, if there are less than 20,000 people in a given ZIP code, or if the complaint has an address outside of the United States).
#
# 11.Tags - Data that supports easier searching and sorting of complaints submitted by or on behalf of consumers.
#
# For example, complaints where the submitter reports the age of the consumer as 62 years or older are tagged “Older American.” Complaints submitted by or on behalf of a servicemember or the spouse or dependent of a servicemember are tagged “Servicemember.” Servicemember includes anyone who is active duty, National Guard, or Reservist, as well as anyone who previously served and is a veteran or retiree.
#
# 12.Consumer consent provided? - Identifies whether the consumer opted in to publish their complaint narrative. It is not published unless the consumer consents, and consumers can opt-out at any time.
#
# 13.Submitted via - How the complaint was submitted to the CFPB. For example, “Web” or “Phone.”
#
# 14.Date sent to company - The date the CFPB sent the complaint to the company.
#
# 15.Company response to consumer - This is how the company responded. For example, “Closed with explanation.”
#
# 16.Timely response? - Whether the company gave a timely response. For example, “Yes” or “No.”
#
# 17.Consumer disputed? - Whether the consumer disputed the company’s response.
#
# 18.Complaint ID - The unique identification number for a complaint.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5157101 entries, 0 to 5157100
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# ...

# %%
date_columns = ['Date received', 'Date sent to company']

# Changing data type for date columns
for i in date_columns:
    data[i] = pd.to_datetime(data[i])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5157101 entries, 0 to 5157100
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 datetime64[ns]
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          datetime64[ns]
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
# ...

# %% [markdown]
# <b>Visualization of Value Counts of Product of Complaints

# %%
Product_value_counts = data['Product'].value_counts()

# Plotting the bar graph
Product_value_counts.plot(kind='bar', figsize=(12, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Product')
plt.xlabel('Product')
plt.ylabel('Count')

# Rotating x-axis labels for better readability
#plt.xticks(rotation=45)

# Adjusting y-axis limits
plt.ylim(0, 2200000) 

# Displaying the plot
plt.show()

# %% [markdown]
# <b>From the Value Counts of type of Product the consumer identified in the complaint. We can see<br>
#     1.Credit reporting, credit repair services, or other personal consumer reports,<br>
#     2.Credit reporting or other personal consumer reports,<br>
#     3.Debt collection <br>
#     Takes the top three spots which suggests that complaints regarding credit reporting and debt collection is more when compared to other complaints, as the most companies involved in the data offer credit reporting as an service.<br>
#
# <b>Where as Virtual Currency complaints is the last spot suggesting that the use of Virtual currency is way less.

# %% [markdown]
# --------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Value Counts of Sub Product of Complaint

# %%
Sub_Product_value_counts = data['Sub-product'].value_counts()

# Plotting the bar graph
Sub_Product_value_counts.plot(kind='bar', figsize=(20, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Sub Product')
plt.xlabel('Sub_Product')
plt.ylabel('Count')

# Adjusting y-axis limits
plt.ylim(0, 3200000)

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Same as Product, Sub_Product also shows that Credit reporting as one the top complaints

# %% [markdown]
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Value Counts of Issues in Complaint

# %%
Issue_value_counts = data['Issue'].value_counts()

# Plotting the bar graph
Issue_value_counts.plot(kind='bar', figsize=(40, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Issue')
plt.xlabel('Issues')
plt.ylabel('Count')

# Adjusting y-axis limits
plt.ylim(0, 1600000) 

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Issues faced by the consumers as mentioned in the complaint,<br>
# 1.Incorrect information on your report<br>
# 2.Improper use of your report<br>
# 3.Problem with a credit reporting company's investigation into an existing problem<br>
# 4.Attempts to collect debt not owed<br>
# 5.Problem with a company's investigation into an existing problem,<br>
#     These issues takes the Top 5 spots, This shows the consumers are not contented with the comapany's investigation and their reported credit score.

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Value Counts of Sub Issues in Complaint

# %%
Sub_Issue_value_counts = data['Sub-issue'].value_counts()

# Plotting the bar graph
Sub_Issue_value_counts.plot(kind='bar', figsize=(60, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Issue')
plt.xlabel('Sub_Issues')
plt.ylabel('Count')

# Adjusting y-axis limits
plt.ylim(0, 1000000)  

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Same as Issue Comulns, Sub-Issue column also shows the consumer discontent and error in reporting,top 5 sub issues are as follows:<br>
# 1.Information belongs to someone else,<br>
# 2.Reporting company used your report improperly,<br>
# 3.Their investigation did not fix an error on your report,<br>
# 4.Credit inquiries on your report that you don't recognize,<br>
# 4.Account information incorrect.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of states with Complaint

# %%
State_value_counts = data['State'].value_counts()

# Plotting the bar graph
State_value_counts.plot(kind='bar', figsize=(15, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Issue')
plt.xlabel('States')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Most Complaints are from Florida,California and Texas compared to other states

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of tags in Complaint

# %%
tags_value_counts = data['Tags'].value_counts()

# Plotting the bar graph
tags_value_counts.plot(kind='bar', figsize=(15, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Tags')
plt.xlabel('Tags')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>From above chart we can say Serviceman are the most used tag in cimplaints

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Tags in each States

# %%
cross_tab = pd.crosstab(data['State'], data['Tags'])

# Plotting the stacked bar chart
cross_tab.plot(kind='bar', stacked=True, figsize=(15, 6))

# Adding title and labels
plt.title('Stacked Bar Chart of Submission methods and Tags')
plt.xlabel('Values')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Even though Servicemen take a lot of numbers,but all the three tags are normally distributed accross the states

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Top 10 Companies with most number of complaints

# %%
data['Company'].value_counts().head(10)
# Out:
# Company
# EQUIFAX, INC.                             1071045
# TRANSUNION INTERMEDIATE HOLDINGS, INC.     992443
# Experian Information Solutions Inc.        902014
# BANK OF AMERICA, NATIONAL ASSOCIATION      140236
# WELLS FARGO & COMPANY                      128377
# JPMORGAN CHASE & CO.                       119088
# CAPITAL ONE FINANCIAL CORPORATION           98826
# CITIBANK, N.A.                              94166
# SYNCHRONY FINANCIAL                         51003
# Navient Solutions, LLC.                     39588
# Name: count, dtype: int64

# %% [markdown]
# <b>The above shows the top 10 compaines that have recieved most amount of complaint.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visulaization of Consent provided by consumer for publishing the complaint narriative

# %%
Consent_value_counts = data['Consumer consent provided?'].value_counts()

# Plotting the bar graph
Consent_value_counts.plot(kind='bar', figsize=(15, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Consent Provided by the Consumer to publish their Complaint Narriative')
plt.xlabel('Consumer consent Provided?')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Above graph shows that most customers are not okay with providing consent to publish their complaint narrative

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Methods used to Submit the Complaints

# %%
Sub_value_counts = data['Submitted via'].value_counts()

# Plotting the bar graph
Sub_value_counts.plot(kind='bar', figsize=(15, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Complaint Submission methods')
plt.xlabel('Submission Methods')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>Web comes out as the most preferred method to submit the complaint

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Compaines Respones to the Complaints

# %%
data['Company response to consumer'].value_counts()
# Out:
# Company response to consumer
# Closed with explanation            3441556
# Closed with non-monetary relief    1294672
# In progress                         215347
# Closed with monetary relief         153249
# Closed without relief                17868
# Closed                               17611
# Untimely response                    11480
# Closed with relief                    5304
# Name: count, dtype: int64

# %%
Response_value_counts = data['Company response to consumer'].value_counts()

# Plotting the bar graph
Response_value_counts.plot(kind='bar', figsize=(15, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Consumer Response to consumer')
plt.xlabel('Responses')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>From the above chart, we can say most of the complaints are closed with explination or some sort of relief. It also shows some complaints are closed with monetary relief which shows the error in the investigation performed by the respective companies

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visualization of Consumer dispute to the response provided by the company

# %%
data['Consumer disputed?'].value_counts()
# Out:
# Consumer disputed?
# No     619938
# Yes    148378
# Name: count, dtype: int64

# %%
Disputed_value_counts = data['Consumer disputed?'].value_counts()

# Plotting the bar graph
Disputed_value_counts.plot(kind='bar', figsize=(10, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Consumer Dispute to response provided by the company')
plt.xlabel('Consumer Disputed')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>We can say most of the consumers are contented with the Response provided by the company

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visulaization of Company Respones Disputed by the consumer

# %%
cross_tab = pd.crosstab(data['Company response to consumer'], data['Consumer disputed?'])

# Plotting the stacked bar chart
cross_tab.plot(kind='bar', stacked=True, figsize=(15, 6))

# Adding title and labels
plt.title('Stacked Bar Chart of Company Response and disputed provided to them by the consumers')
plt.xlabel('Values')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>From Above chart we can say complaints closed by explination are mostly disputed by consumers follwed by complaints closed with non-monetary relief.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Visulaizaton of Timely Responses from the Company.

# %%
data['Timely response?'].value_counts()
# Out:
# Timely response?
# Yes    5098601
# No       58500
# Name: count, dtype: int64

# %%
T_value_counts = data['Timely response?'].value_counts()

# Plotting the bar graph
T_value_counts.plot(kind='bar', figsize=(6, 6), color='skyblue', edgecolor='black')

# Adding title and labels
plt.title('Value Counts of Timely Respones from the Comapany')
plt.xlabel('responses')
plt.ylabel('Count')

# Displaying the plot
plt.show()

# %% [markdown]
# <b>From Above graph, we can say most of the complaints were timely responded.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Question : 2

# %% [markdown]
# <b>2. Given an unsorted array of integers, find the length of the longest continuous increasing subsequence (subarray). <br>
# Example 1:<br>
# Input: [1,3,5,4,7]
# Output: 3 <br>
# Example 2:<br>
# Input: [2,2,2,2,2]<br>
# Output: 1<br>

# %%
def find_length_of_LCIS(nums):
    if not nums:
        return 0
    
    max_length = 1
    current_length = 1
    
    for i in range(1, len(nums)):
        if nums[i] > nums[i - 1]:
            current_length += 1
            max_length = max(max_length, current_length)
        else:
            current_length = 1
    
    return max_length

# Test cases
print('Example 1 Output: ',find_length_of_LCIS([1, 3, 5, 4, 7]))
print('Example 2 Output: ',find_length_of_LCIS([2, 2, 2, 2, 2]))
print('Example 3 Output: ',find_length_of_LCIS([40,1,3,10,15,2,25,25,35,20]))
# Out:
# Example 1 Output:  3
# Example 2 Output:  1
# Example 3 Output:  4

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Question : 3

# %% [markdown]
# <b>3. Given a list of non negative integers, arrange them such that they form the largest number.<br>
#  Example 1:<br>
#  Input: [10,2]<br>
#  Output: "210"<br>
#  Example 2:<br>
#  Input: [3,30,34,5,9]<br>
#  Output: "9534330"<br>

# %%
from typing import List

def largest_number(nums: List[int]) -> str:
    # Custom sorting function
    def compare(x, y):
        xy = x + y
        yx = y + x
        return (xy > yx) - (xy < yx)

    # Convert integers to strings
    nums_str = [str(num) for num in nums]

    # Sort the strings using the custom sorting function
    nums_str.sort(key=lambda x: (x, x[0]), reverse=True)

    # Concatenate the sorted strings
    largest_num = ''.join(nums_str)

    return largest_num

# Test cases
print('Example 1 Output:', largest_number([10, 2]))  # Output: "210"
print('Example 2 Output:', largest_number([3, 30, 34, 5, 9]))  # Output: "9534330"
print('Example 3 Output:', largest_number([0, 7, 1001, 5, 501]))  # Output: "750510011"
# Out:
# Example 1 Output: 210
# Example 2 Output: 9534303
# Example 3 Output: 7501510010

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Question : 4

# %% [markdown]
# <b>4. Store all the "servlet-name", and "servlet-class" to a csv file from the attached sample_json.json file using Python.

# %%
import json
import csv

file_path = 'C:\My Documents\Adapt Ready Assignment Excelr\DT A1 sample_json (1) (1).json'

with open(file_path, 'r') as file:
    # Load the JSON data
    df = json.load(file)

# %%
df
# Out:
# {'web-app': {'servlet': [{'servlet-name': 'cofaxCDS',
#     'servlet-class': 'org.cofax.cds.CDSServlet',
#     'init-param': {'configGlossary:installationAt': 'Philadelphia, PA',
#      'configGlossary:adminEmail': 'ksm@pobox.com',
#      'configGlossary:poweredBy': 'Cofax',
#      'configGlossary:poweredByIcon': '/images/cofax.gif',
#      'configGlossary:staticPath': '/content/static',
#      'templateProcessorClass': 'org.cofax.WysiwygTemplate',
#      'templateLoaderClass': 'org.cofax.FilesTemplateLoader',
#      'templatePath': 'templates',
#      'templateOverridePath': '',
#      'defaultListTemplate': 'listTemplate.htm',
#      'defaultFileTemplate': 'articleTemplate.htm',
#      'useJSP': 'false',
#      'jspListTemplate': 'listTemplate.jsp',
#      'jspFileTemplate': 'articleTemplate.jsp',
#      'cachePackageTagsTrack': 200,
#      'cachePackageTagsStore': 200,
#      'cachePackageTagsRefresh': 60,
#      'cacheTemplatesTrack': 100,
#      'cacheTemplatesStore': 50,
# ...

# %%
# Extract "servlet-name" and "servlet-class" information
servlet_info = [(servlet['servlet-name'], servlet['servlet-class']) for servlet in df['web-app']['servlet']]

# Write the extracted information to a CSV file
with open('servlet_info.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    # Write header
    writer.writerow(['servlet-name', 'servlet-class'])
    # Write data
    writer.writerows(servlet_info)

print("Data has been stored to servlet_info.csv file.")
# Out:
# Data has been stored to servlet_info.csv file.

# %%
csv_file = pd.read_csv(r'C:\Users\SPURGE\Documents\Adapt Ready Assignment\servlet_info.csv')
csv_file
# Out:
#   servlet-name                    servlet-class
# 0     cofaxCDS         org.cofax.cds.CDSServlet
# 1   cofaxEmail       org.cofax.cds.EmailServlet
# 2   cofaxAdmin       org.cofax.cds.AdminServlet
# 3  fileServlet        org.cofax.cds.FileServlet
# 4   cofaxTools  org.cofax.cms.CofaxToolsServlet
